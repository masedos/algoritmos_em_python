# %% [markdown]
# # Tratamento de erros e exceções
#
# - NameError: variável nao foi definida
# - TypeError: tipos de dados incompatíveis
# - RuntimeError: erro de execução
# - SyntaxError: sintaxe digitada é inválida e não reconhecida pelo interpretador
# - ZeroDivisionError: divisão por zero
# - IndexError: índice está fora da coleção

# %% [markdown]
# ## Tipos de erros

# %%
3 = 4
# Out:
#   Cell In[11], line 1
#     3 = 4
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
print('Meu nome é', nome)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print('Meu nome é', nome)
#
# NameError: name 'nome' is not defined

# %%
print(3 / 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(3 / 0)
#
# ZeroDivisionError: division by zero

# %%
2.3 / 'cachorro'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 2.3 / 'cachorro'
#
# TypeError: unsupported operand type(s) for /: 'float' and 'str'

# %%
c = [1,2,3,4,5]
c
# Out:
# [1, 2, 3, 4, 5]

# %%
c[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 c[5]
#
# IndexError: list index out of range

# %% [markdown]
# ## Tratamento de erros

# %%
try:
  n = int(input('Digite um número inteiro: '))
except:
  print('Valor inválido')
else:
  print(f'Valor digitado é {n}')
# Out:
# Digite um número inteiro:  545
# Valor digitado é 545

# %%
while True:
  try:
    n = int(input('Digite um número inteiro: '))
  except:
    print('Valor inválido')
  else:
    print(f'Valor digitado é {n}')
    break
# Out:
# Digite um número inteiro:  787
# Valor digitado é 787

# %%
while True:
  try:
    p = int(input('Digite um número inteiro'))
  except ValueError:
    print('Valor inválido')
  except KeyboardInterrupt:
    print('Usuário interrompeu a execução')
    break
  else:
    print(f'Valor digitado é {p}')
    break
# Out:
# Digite um número inteiro 987
# Valor digitado é 987
